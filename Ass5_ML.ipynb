# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
data = df[['SALES', 'QUANTITYORDERED', 'PRICEEACH']]
data
# Out:
#         SALES  QUANTITYORDERED  PRICEEACH
# 0     2871.00               30      95.70
# 1     2765.90               34      81.35
# 2     3884.34               41      94.74
# 3     3746.70               45      83.26
# 4     5205.27               49     100.00
# ...       ...              ...        ...
# 2818  2244.40               20     100.00
# 2819  3978.51               29     100.00
# 2820  5417.57               43     100.00
# 2821  2116.16               34      62.24
# 2822  3079.44               47      65.52
#
# [2823 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# SALES              0
# QUANTITYORDERED    0
# PRICEEACH          0
# dtype: int64

# %%
# Standardize the data for better clustering performance
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(cluster_range, inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
data.loc[:, 'Cluster'] = kmeans.fit_predict(data_scaled)
data
# Out:
#         SALES  QUANTITYORDERED  PRICEEACH  Cluster
# 0     2871.00               30      95.70        1
# 1     2765.90               34      81.35        1
# 2     3884.34               41      94.74        2
# 3     3746.70               45      83.26        2
# 4     5205.27               49     100.00        2
# ...       ...              ...        ...      ...
# 2818  2244.40               20     100.00        1
# 2819  3978.51               29     100.00        1
# 2820  5417.57               43     100.00        2
# 2821  2116.16               34      62.24        0
# 2822  3079.44               47      65.52        0
#
# [2823 rows x 4 columns]

# %%
##Ass done 
# Do some extra for explaining something

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data['SALES'], data['QUANTITYORDERED'], data['PRICEEACH'], c=data['Cluster'], cmap='viridis')
ax.set_xlabel('Sales')
ax.set_ylabel('Quantity Ordered')
ax.set_zlabel('Price Each')
plt.title('K-Means Clustering')
plt.colorbar(scatter)
plt.show()
