# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the function
def f(x):
    return (x + 3) ** 2

# %%
# Define the gradient of the function
def gradient(x):
    return 2 * (x + 3)

# %%
# Start point
x_current = 2  # Starting at x = 2
learning_rate = 0.1  # Step size for each iteration
iterations = 20  # Number of iterations to converge

# %%
# Cell 4: Implement Gradient Descent loop

# List to store x and y values for each iteration
x_values = []
y_values = []

for i in range(iterations):
    grad = gradient(x_current)  # Calculate the gradient at current x
    x_current = x_current - learning_rate * grad  # Update x by moving in the direction of the negative gradient
    y_current = f(x_current)  # Calculate the new y value for updated x
    
    # Append current x and y values to lists for tracking
    x_values.append(x_current)
    y_values.append(y_current)
    
    # Print the current state at each iteration
    print(f"Iteration {i+1}: x = {x_current}, y = {y_current}")

print(f"\nLocal minimum occurs at x = {x_current}, y = {y_current}")
# Out:
# Iteration 1: x = 1.0, y = 16.0
# Iteration 2: x = 0.19999999999999996, y = 10.240000000000002
# Iteration 3: x = -0.44000000000000017, y = 6.553599999999998
# Iteration 4: x = -0.9520000000000001, y = 4.194304
# Iteration 5: x = -1.3616000000000001, y = 2.6843545599999996
# Iteration 6: x = -1.6892800000000001, y = 1.7179869183999996
# Iteration 7: x = -1.951424, y = 1.099511627776
# Iteration 8: x = -2.1611392, y = 0.7036874417766399
# Iteration 9: x = -2.32891136, y = 0.4503599627370493
# Iteration 10: x = -2.463129088, y = 0.28823037615171165
# Iteration 11: x = -2.5705032704, y = 0.1844674407370954
# Iteration 12: x = -2.6564026163200003, y = 0.11805916207174093
# Iteration 13: x = -2.725122093056, y = 0.07555786372591429
# Iteration 14: x = -2.7800976744448, y = 0.04835703278458515
# Iteration 15: x = -2.82407813955584, y = 0.030948500982134555
# Iteration 16: x = -2.8592625116446717, y = 0.019807040628566166
# Iteration 17: x = -2.8874100093157375, y = 0.012676506002282305
# ...

# %%
# Cell 5: (Optional) Visualize the gradient descent process using matplotlib

import matplotlib.pyplot as plt

# Plot y values over iterations to visualize convergence
plt.plot(range(iterations), y_values, marker='o', color='b')
plt.title("Gradient Descent Convergence")
plt.xlabel("Iteration")
plt.ylabel("Function Value y = (x + 3)^2")
plt.show()
